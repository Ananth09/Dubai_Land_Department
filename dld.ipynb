# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananth09/Dubai_Land_Department/blob/main/dld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Transactionstxt.txt',encoding='windows-1256')

# %%
df
# Out:
#       transaction_id  procedure_id  trans_group_id  \
# 0    1-11-2024-10138            11               1
# 1        3-9-2002-39             9               3
# 2    1-11-2016-12930            11               1
# 3   1-11-2005-300028            11               1
# 4    1-11-2010-17709            11               1
# ..               ...           ...             ...
# 94    1-11-2004-1620            11               1
# 95      1-11-2002-45            11               1
# 96    1-11-2005-1742            11               1
# 97     1-11-1999-296            11               1
# 98    1-11-2024-1130            11               1
#
#                    trans_group_ar trans_group_en procedure_name_ar  \
# 0   أ™â€¦أکآ¨أکآ§أ™إ أکآ¹أکآ§أکآھ          Sales      أکآ¨أ™إ أکآ¹
# 1               أ™â€،أکآ¨أکآ§أکآھ          Gifts    أ™â€،أکآ¨أ™â€،
# 2   أ™â€¦أکآ¨أکآ§أ™إ أکآ¹أکآ§أکآھ          Sales      أکآ¨أ™إ أکآ¹
# 3   أ™â€¦أکآ¨أکآ§أ™إ أکآ¹أکآ§أکآھ          Sales      أکآ¨أ™إ أکآ¹
# 4   أ™â€¦أکآ¨أکآ§أ™إ أکآ¹أکآ§أکآھ          Sales      أکآ¨أ™إ أکآ¹
# ..                            ...            ...               ...
# 94  أ™â€¦أکآ¨أکآ§أ™إ أکآ¹أکآ§أکآھ          Sales      أکآ¨أ™إ أکآ¹
# 95  أ™â€¦أکآ¨أکآ§أ™إ أکآ¹أکآ§أکآھ          Sales      أکآ¨أ™إ أکآ¹
# 96  أ™â€¦أکآ¨أکآ§أ™إ أکآ¹أکآ§أکآھ          Sales      أکآ¨أ™إ أکآ¹
# 97  أ™â€¦أکآ¨أکآ§أ™إ أکآ¹أکآ§أکآھ          Sales      أکآ¨أ™إ أکآ¹
# 98  أ™â€¦أکآ¨أکآ§أ™إ أکآ¹أکآ§أکآھ          Sales      أکآ¨أ™إ أکآ¹
#
#    procedure_name_en instance_date  property_type_id     property_type_ar  \
# 0               Sell    19-03-2024                 4    أ™آپأ™إ أ™â€‍أکآ§
# 1              Grant    25-03-2002                 1         أکآ£أکآ±أکآ¶
# 2               Sell    02-11-2016                 4    أ™آپأ™إ أ™â€‍أکآ§
# 3               Sell    28-02-2005                 4    أ™آپأ™إ أ™â€‍أکآ§
# 4               Sell    09-12-2010                 2  أ™â€¦أکآ¨أ™â€ أ™â€°
# ..               ...           ...               ...                  ...
# 94              Sell    21-07-2004                 4    أ™آپأ™إ أ™â€‍أکآ§
# 95              Sell    08-01-2002                 4    أ™آپأ™إ أ™â€‍أکآ§
# 96              Sell    08-08-2005                 4    أ™آپأ™إ أ™â€‍أکآ§
# 97              Sell    24-05-1999                 4    أ™آپأ™إ أ™â€‍أکآ§
# 98              Sell    12-01-2024                 1         أکآ£أکآ±أکآ¶
#
#     ... rooms_en  has_parking  procedure_area  actual_worth meter_sale_price  \
# 0   ...      NaN            0         1305.29     5769000.0          4419.71
# 1   ...      NaN            0         1466.94     1105300.0           753.47
# 2   ...      NaN            0          390.00     2089900.0          5358.72
# 3   ...      NaN            0          396.09      511612.0          1291.66
# 4   ...      NaN            0          559.18     5700000.0         10193.50
# ..  ...      ...          ...             ...           ...              ...
# 94  ...      NaN            0          672.34      723700.0          1076.39
# 95  ...      NaN            0         1393.55      900000.0           645.83
# 96  ...      NaN            0          929.03     2700000.0          2906.26
# 97  ...      NaN            0          929.03      380000.0           409.03
# 98  ...      NaN            0         1393.55     5300000.0          3803.24
#
#    rent_value  meter_rent_price no_of_parties_role_1 no_of_parties_role_2  \
# 0         NaN               NaN                    8                    1
# 1         NaN               NaN                    1                    1
# 2         NaN               NaN                    1                    1
# 3         NaN               NaN                    1                    1
# 4         NaN               NaN                    1                    1
# ..        ...               ...                  ...                  ...
# 94        NaN               NaN                    1                    1
# 95        NaN               NaN                    1                    1
# 96        NaN               NaN                    1                    1
# 97        NaN               NaN                    1                    1
# 98        NaN               NaN                    7                    2
#
#     no_of_parties_role_3
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ..                   ...
# 94                     0
# 95                     0
# 96                     0
# 97                     0
# 98                     0
#
# [99 rows x 46 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 46 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   transaction_id        99 non-null     object
#  1   procedure_id          99 non-null     int64
#  2   trans_group_id        99 non-null     int64
#  3   trans_group_ar        99 non-null     object
#  4   trans_group_en        99 non-null     object
#  5   procedure_name_ar     99 non-null     object
#  6   procedure_name_en     99 non-null     object
#  7   instance_date         99 non-null     object
#  8   property_type_id      99 non-null     int64
#  9   property_type_ar      99 non-null     object
#  10  property_type_en      99 non-null     object
#  11  property_sub_type_id  0 non-null      float64
#  12  property_sub_type_ar  0 non-null      float64
#  13  property_sub_type_en  0 non-null      float64
#  14  property_usage_ar     99 non-null     object
#  15  property_usage_en     99 non-null     object
#  16  reg_type_id           99 non-null     int64
#  17  reg_type_ar           99 non-null     object
#  18  reg_type_en           99 non-null     object
#  19  area_id               99 non-null     int64
#  20  area_name_ar          99 non-null     object
#  21  area_name_en          99 non-null     object
#  22  building_name_ar      0 non-null      float64
#  23  building_name_en      0 non-null      float64
#  24  project_number        0 non-null      float64
#  25  project_name_ar       0 non-null      float64
#  26  project_name_en       0 non-null      float64
#  27  master_project_en     0 non-null      float64
#  28  master_project_ar     0 non-null      float64
#  29  nearest_landmark_ar   99 non-null     object
#  30  nearest_landmark_en   99 non-null     object
#  31  nearest_metro_ar      99 non-null     object
#  32  nearest_metro_en      99 non-null     object
#  33  nearest_mall_ar       97 non-null     object
#  34  nearest_mall_en       97 non-null     object
#  35  rooms_ar              0 non-null      float64
#  36  rooms_en              0 non-null      float64
#  37  has_parking           99 non-null     int64
#  38  procedure_area        99 non-null     float64
#  39  actual_worth          99 non-null     float64
#  40  meter_sale_price      99 non-null     float64
#  41  rent_value            0 non-null      float64
#  42  meter_rent_price      0 non-null      float64
#  43  no_of_parties_role_1  99 non-null     int64
#  44  no_of_parties_role_2  99 non-null     int64
#  45  no_of_parties_role_3  99 non-null     int64
# dtypes: float64(17), int64(9), object(20)
# memory usage: 35.7+ KB
# None

# %%
# Drop columns ending with 'ar'
df = df[df.columns.drop(list(df.filter(regex='ar$')))]

# %%
df
# Out:
#       transaction_id  procedure_id  trans_group_id trans_group_en  \
# 0    1-11-2024-10138            11               1          Sales
# 1        3-9-2002-39             9               3          Gifts
# 2    1-11-2016-12930            11               1          Sales
# 3   1-11-2005-300028            11               1          Sales
# 4    1-11-2010-17709            11               1          Sales
# ..               ...           ...             ...            ...
# 94    1-11-2004-1620            11               1          Sales
# 95      1-11-2002-45            11               1          Sales
# 96    1-11-2005-1742            11               1          Sales
# 97     1-11-1999-296            11               1          Sales
# 98    1-11-2024-1130            11               1          Sales
#
#    procedure_name_en instance_date  property_type_id property_type_en  \
# 0               Sell    19-03-2024                 4            Villa
# 1              Grant    25-03-2002                 1             Land
# 2               Sell    02-11-2016                 4            Villa
# 3               Sell    28-02-2005                 4            Villa
# 4               Sell    09-12-2010                 2         Building
# ..               ...           ...               ...              ...
# 94              Sell    21-07-2004                 4            Villa
# 95              Sell    08-01-2002                 4            Villa
# 96              Sell    08-08-2005                 4            Villa
# 97              Sell    24-05-1999                 4            Villa
# 98              Sell    12-01-2024                 1             Land
#
#     property_sub_type_id  property_sub_type_en  ... rooms_en  has_parking  \
# 0                    NaN                   NaN  ...      NaN            0
# 1                    NaN                   NaN  ...      NaN            0
# 2                    NaN                   NaN  ...      NaN            0
# 3                    NaN                   NaN  ...      NaN            0
# 4                    NaN                   NaN  ...      NaN            0
# ..                   ...                   ...  ...      ...          ...
# 94                   NaN                   NaN  ...      NaN            0
# 95                   NaN                   NaN  ...      NaN            0
# 96                   NaN                   NaN  ...      NaN            0
# 97                   NaN                   NaN  ...      NaN            0
# 98                   NaN                   NaN  ...      NaN            0
#
#    procedure_area  actual_worth meter_sale_price  rent_value  \
# 0         1305.29     5769000.0          4419.71         NaN
# 1         1466.94     1105300.0           753.47         NaN
# 2          390.00     2089900.0          5358.72         NaN
# 3          396.09      511612.0          1291.66         NaN
# 4          559.18     5700000.0         10193.50         NaN
# ..            ...           ...              ...         ...
# 94         672.34      723700.0          1076.39         NaN
# 95        1393.55      900000.0           645.83         NaN
# 96         929.03     2700000.0          2906.26         NaN
# 97         929.03      380000.0           409.03         NaN
# 98        1393.55     5300000.0          3803.24         NaN
#
#     meter_rent_price  no_of_parties_role_1  no_of_parties_role_2  \
# 0                NaN                     8                     1
# 1                NaN                     1                     1
# 2                NaN                     1                     1
# 3                NaN                     1                     1
# 4                NaN                     1                     1
# ..               ...                   ...                   ...
# 94               NaN                     1                     1
# 95               NaN                     1                     1
# 96               NaN                     1                     1
# 97               NaN                     1                     1
# 98               NaN                     7                     2
#
#    no_of_parties_role_3
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 94                    0
# 95                    0
# 96                    0
# 97                    0
# 98                    0
#
# [99 rows x 32 columns]

# %%
print(df.isnull().sum())
# Out:
# transaction_id           0
# procedure_id             0
# trans_group_id           0
# trans_group_en           0
# procedure_name_en        0
# instance_date            0
# property_type_id         0
# property_type_en         0
# property_sub_type_id    99
# property_sub_type_en    99
# property_usage_en        0
# reg_type_id              0
# reg_type_en              0
# area_id                  0
# area_name_en             0
# building_name_en        99
# project_number          99
# project_name_en         99
# master_project_en       99
# nearest_landmark_en      0
# nearest_metro_en         0
# nearest_mall_en          2
# rooms_en                99
# has_parking              0
# procedure_area           0
# actual_worth             0
# meter_sale_price         0
# rent_value              99
# meter_rent_price        99
# no_of_parties_role_1     0
# no_of_parties_role_2     0
# no_of_parties_role_3     0
# dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#       transaction_id  procedure_id  trans_group_id trans_group_en  \
# 0    1-11-2024-10138            11               1          Sales
# 1        3-9-2002-39             9               3          Gifts
# 2    1-11-2016-12930            11               1          Sales
# 3   1-11-2005-300028            11               1          Sales
# 4    1-11-2010-17709            11               1          Sales
# ..               ...           ...             ...            ...
# 94    1-11-2004-1620            11               1          Sales
# 95      1-11-2002-45            11               1          Sales
# 96    1-11-2005-1742            11               1          Sales
# 97     1-11-1999-296            11               1          Sales
# 98    1-11-2024-1130            11               1          Sales
#
#    procedure_name_en instance_date  property_type_id property_type_en  \
# 0               Sell    19-03-2024                 4            Villa
# 1              Grant    25-03-2002                 1             Land
# 2               Sell    02-11-2016                 4            Villa
# 3               Sell    28-02-2005                 4            Villa
# 4               Sell    09-12-2010                 2         Building
# ..               ...           ...               ...              ...
# 94              Sell    21-07-2004                 4            Villa
# 95              Sell    08-01-2002                 4            Villa
# 96              Sell    08-08-2005                 4            Villa
# 97              Sell    24-05-1999                 4            Villa
# 98              Sell    12-01-2024                 1             Land
#
#     property_sub_type_id  property_sub_type_en         property_usage_en  \
# 0                    NaN                   NaN               Residential
# 1                    NaN                   NaN               Residential
# 2                    NaN                   NaN               Residential
# 3                    NaN                   NaN               Residential
# 4                    NaN                   NaN  Residential / Commercial
# ..                   ...                   ...                       ...
# 94                   NaN                   NaN               Residential
# 95                   NaN                   NaN               Residential
# 96                   NaN                   NaN               Residential
# 97                   NaN                   NaN               Residential
# 98                   NaN                   NaN               Residential
#
#     reg_type_id          reg_type_en  area_id area_name_en  building_name_en  \
# 0             1  Existing Properties      278     Mankhool               NaN
# 1             1  Existing Properties      365   Al Hudaiba               NaN
# 2             1  Existing Properties      276      Al Bada               NaN
# 3             1  Existing Properties      276      Al Bada               NaN
# 4             1  Existing Properties      276      Al Bada               NaN
# ..          ...                  ...      ...          ...               ...
# 94            1  Existing Properties      232       Mirdif               NaN
# 95            1  Existing Properties      232       Mirdif               NaN
# 96            1  Existing Properties      232       Mirdif               NaN
# 97            1  Existing Properties      232       Mirdif               NaN
# 98            1  Existing Properties      232       Mirdif               NaN
#
#     project_number  project_name_en  master_project_en  \
# 0              NaN              NaN                NaN
# 1              NaN              NaN                NaN
# 2              NaN              NaN                NaN
# 3              NaN              NaN                NaN
# 4              NaN              NaN                NaN
# ..             ...              ...                ...
# 94             NaN              NaN                NaN
# 95             NaN              NaN                NaN
# 96             NaN              NaN                NaN
# 97             NaN              NaN                NaN
# 98             NaN              NaN                NaN
#
#             nearest_landmark_en               nearest_metro_en  \
# 0                  Burj Khalifa             ADCB Metro Station
# 1                  Burj Khalifa             ADCB Metro Station
# 2                  Burj Khalifa  Emirates Towers Metro Station
# 3                  Burj Khalifa     Trade Centre Metro Station
# 4                  Burj Khalifa     Trade Centre Metro Station
# ..                          ...                            ...
# 94  Dubai International Airport        Rashidiya Metro Station
# 95  Dubai International Airport        Rashidiya Metro Station
# 96  Dubai International Airport        Rashidiya Metro Station
# 97  Dubai International Airport        Rashidiya Metro Station
# 98  Dubai International Airport         Etisalat Metro Station
#
#        nearest_mall_en  rooms_en  has_parking  procedure_area  actual_worth  \
# 0           Dubai Mall       NaN            0         1305.29     5769000.0
# 1           Dubai Mall       NaN            0         1466.94     1105300.0
# 2           Dubai Mall       NaN            0          390.00     2089900.0
# 3           Dubai Mall       NaN            0          396.09      511612.0
# 4           Dubai Mall       NaN            0          559.18     5700000.0
# ..                 ...       ...          ...             ...           ...
# 94  City Centre Mirdif       NaN            0          672.34      723700.0
# 95  City Centre Mirdif       NaN            0         1393.55      900000.0
# 96  City Centre Mirdif       NaN            0          929.03     2700000.0
# 97  City Centre Mirdif       NaN            0          929.03      380000.0
# 98  City Centre Mirdif       NaN            0         1393.55     5300000.0
#
#     meter_sale_price  rent_value  meter_rent_price  no_of_parties_role_1  \
# 0            4419.71         NaN               NaN                     8
# 1             753.47         NaN               NaN                     1
# 2            5358.72         NaN               NaN                     1
# 3            1291.66         NaN               NaN                     1
# 4           10193.50         NaN               NaN                     1
# ..               ...         ...               ...                   ...
# 94           1076.39         NaN               NaN                     1
# 95            645.83         NaN               NaN                     1
# 96           2906.26         NaN               NaN                     1
# 97            409.03         NaN               NaN                     1
# 98           3803.24         NaN               NaN                     7
#
#     no_of_parties_role_2  no_of_parties_role_3
# 0                      1                     0
# 1                      1                     0
# 2                      1                     0
# 3                      1                     0
# 4                      1                     0
# ..                   ...                   ...
# 94                     1                     0
# 95                     1                     0
# 96                     1                     0
# 97                     1                     0
# 98                     2                     0
#
# [99 rows x 32 columns]

# %%
df=df.dropna(axis=1,how='all')
df
# Out:
#       transaction_id  procedure_id  trans_group_id trans_group_en  \
# 0    1-11-2024-10138            11               1          Sales
# 1        3-9-2002-39             9               3          Gifts
# 2    1-11-2016-12930            11               1          Sales
# 3   1-11-2005-300028            11               1          Sales
# 4    1-11-2010-17709            11               1          Sales
# ..               ...           ...             ...            ...
# 94    1-11-2004-1620            11               1          Sales
# 95      1-11-2002-45            11               1          Sales
# 96    1-11-2005-1742            11               1          Sales
# 97     1-11-1999-296            11               1          Sales
# 98    1-11-2024-1130            11               1          Sales
#
#    procedure_name_en instance_date  property_type_id property_type_en  \
# 0               Sell    19-03-2024                 4            Villa
# 1              Grant    25-03-2002                 1             Land
# 2               Sell    02-11-2016                 4            Villa
# 3               Sell    28-02-2005                 4            Villa
# 4               Sell    09-12-2010                 2         Building
# ..               ...           ...               ...              ...
# 94              Sell    21-07-2004                 4            Villa
# 95              Sell    08-01-2002                 4            Villa
# 96              Sell    08-08-2005                 4            Villa
# 97              Sell    24-05-1999                 4            Villa
# 98              Sell    12-01-2024                 1             Land
#
#            property_usage_en  reg_type_id          reg_type_en  area_id  \
# 0                Residential            1  Existing Properties      278
# 1                Residential            1  Existing Properties      365
# 2                Residential            1  Existing Properties      276
# 3                Residential            1  Existing Properties      276
# 4   Residential / Commercial            1  Existing Properties      276
# ..                       ...          ...                  ...      ...
# 94               Residential            1  Existing Properties      232
# 95               Residential            1  Existing Properties      232
# 96               Residential            1  Existing Properties      232
# 97               Residential            1  Existing Properties      232
# 98               Residential            1  Existing Properties      232
#
#    area_name_en          nearest_landmark_en               nearest_metro_en  \
# 0      Mankhool                 Burj Khalifa             ADCB Metro Station
# 1    Al Hudaiba                 Burj Khalifa             ADCB Metro Station
# 2       Al Bada                 Burj Khalifa  Emirates Towers Metro Station
# 3       Al Bada                 Burj Khalifa     Trade Centre Metro Station
# 4       Al Bada                 Burj Khalifa     Trade Centre Metro Station
# ..          ...                          ...                            ...
# 94       Mirdif  Dubai International Airport        Rashidiya Metro Station
# 95       Mirdif  Dubai International Airport        Rashidiya Metro Station
# 96       Mirdif  Dubai International Airport        Rashidiya Metro Station
# 97       Mirdif  Dubai International Airport        Rashidiya Metro Station
# 98       Mirdif  Dubai International Airport         Etisalat Metro Station
#
#        nearest_mall_en  has_parking  procedure_area  actual_worth  \
# 0           Dubai Mall            0         1305.29     5769000.0
# 1           Dubai Mall            0         1466.94     1105300.0
# 2           Dubai Mall            0          390.00     2089900.0
# 3           Dubai Mall            0          396.09      511612.0
# 4           Dubai Mall            0          559.18     5700000.0
# ..                 ...          ...             ...           ...
# 94  City Centre Mirdif            0          672.34      723700.0
# 95  City Centre Mirdif            0         1393.55      900000.0
# 96  City Centre Mirdif            0          929.03     2700000.0
# 97  City Centre Mirdif            0          929.03      380000.0
# 98  City Centre Mirdif            0         1393.55     5300000.0
#
#     meter_sale_price  no_of_parties_role_1  no_of_parties_role_2  \
# 0            4419.71                     8                     1
# 1             753.47                     1                     1
# 2            5358.72                     1                     1
# 3            1291.66                     1                     1
# 4           10193.50                     1                     1
# ..               ...                   ...                   ...
# 94           1076.39                     1                     1
# 95            645.83                     1                     1
# 96           2906.26                     1                     1
# 97            409.03                     1                     1
# 98           3803.24                     7                     2
#
#     no_of_parties_role_3
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ..                   ...
# 94                     0
# 95                     0
# 96                     0
# 97                     0
# 98                     0
#
# [99 rows x 23 columns]

# %%
print(df.isnull().sum())
# Out:
# transaction_id          0
# procedure_id            0
# trans_group_id          0
# trans_group_en          0
# procedure_name_en       0
# instance_date           0
# property_type_id        0
# property_type_en        0
# property_usage_en       0
# reg_type_id             0
# reg_type_en             0
# area_id                 0
# area_name_en            0
# nearest_landmark_en     0
# nearest_metro_en        0
# nearest_mall_en         2
# has_parking             0
# procedure_area          0
# actual_worth            0
# meter_sale_price        0
# no_of_parties_role_1    0
# no_of_parties_role_2    0
# no_of_parties_role_3    0
# dtype: int64

# %%
df.loc[:, 'nearest_mall_en'] = df['nearest_mall_en'].fillna(df['nearest_mall_en'].mode()[0])

# %%
total_transactions = df['transaction_id'].nunique()
print(f"Total Transactions: {total_transactions}")
# Out:
# Total Transactions: 99

# %%
df['instance_year'] = pd.to_datetime(df['instance_date']).dt.year
yearly_transactions = df['instance_year'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
sns.lineplot(x=yearly_transactions.index, y=yearly_transactions.values, marker='o')
plt.xlabel("Year")
plt.ylabel("Number of Transactions")
plt.title("Transactions Over the Years")
plt.show()
# Out:
# <ipython-input-14-75ed8f040220>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['instance_year'] = pd.to_datetime(df['instance_date']).dt.year
# <ipython-input-14-75ed8f040220>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['instance_year'] = pd.to_datetime(df['instance_date']).dt.year

# %%
property_counts = df['property_type_en'].value_counts()

plt.figure(figsize=(8, 5))
sns.barplot(x=property_counts.values, y=property_counts.index)
plt.xlabel("Number of Transactions")
plt.ylabel("Property Type")
plt.title("Distribution of Property Types")
plt.show()

# %%
price_summary = df.groupby('property_type_en').agg({'meter_sale_price': 'mean'})
print(price_summary)

price_summary.plot(kind='bar', figsize=(10, 5))
plt.ylabel("Price per meter (Mean)")
plt.title("Average Sale Price per Meter")
plt.show()
# Out:
#                   meter_sale_price
# property_type_en
# Building              19158.030556
# Land                  11792.653636
# Villa                  2775.132500

# %%
price_summary = df.groupby('property_type_en').agg({'actual_worth': 'mean'})
print(price_summary)

price_summary.plot(kind='bar', figsize=(10, 5))
plt.ylabel("Actual Worth (Mean)")
plt.title("Average Property Worth")
plt.show()
# Out:
#                   actual_worth
# property_type_en
# Building          2.827466e+07
# Land              3.669771e+07
# Villa             3.705081e+06

# %%
area_prices = df.groupby('area_name_en')['meter_sale_price'].mean().sort_values()

plt.figure(figsize=(12, 5))
sns.barplot(x=area_prices.index, y=area_prices.values)
plt.xticks(rotation=90)
plt.ylabel("Mean Sale Price per Meter")
plt.title("Most Expensive & Cheapest Areas")
plt.show()

# %%
yearly_price_trends = df.groupby('instance_year')['meter_sale_price'].mean()

plt.figure(figsize=(10, 5))
sns.lineplot(x=yearly_price_trends.index, y=yearly_price_trends.values, marker='o')
plt.xlabel("Year")
plt.ylabel("Average Price per Meter")
plt.title("Price Trends Over Time")
plt.show()

# %%
parking_comparison = df.groupby('has_parking')[['actual_worth', 'meter_sale_price']].mean()
print(parking_comparison)

parking_comparison.plot(kind='bar', figsize=(8, 5))
plt.title("Property Prices: With vs. Without Parking")
plt.ylabel("Mean Price")
plt.xticks(ticks=[0, 1], labels=["No Parking", "Has Parking"], rotation=0)
plt.show()
# Out:
#              actual_worth  meter_sale_price
# has_parking
# 0            1.630532e+07       9734.496768

# %%
# Summing up the number of parties involved per property type
property_party_summary = df.groupby("property_type_en")[
    ["no_of_parties_role_1", "no_of_parties_role_2", "no_of_parties_role_3"]
].sum()

# Plotting the results
plt.figure(figsize=(10, 6))
property_party_summary.plot(kind="bar", stacked=True, colormap="viridis", figsize=(12, 6))
plt.title("Total Number of Parties Involved by Property Type")
plt.ylabel("Number of Parties")
plt.xlabel("Property Type")
plt.xticks(rotation=45)
plt.legend(title="Roles", labels=["Role 1", "Role 2", "Role 3"])
plt.show()
